# %% [markdown]
# # Introduction to Polars
#
# [Polars](https://github.com/pola-rs/polars) is a fast DataFrame library for data wrangling/analytics. Like pandas, it lets you load, transform, join, group, and aggregate tabular data---but it's built with a different performance model:
#
# - **Engine:** written in Rust (pandas is mostly Python with NumPy/C extensions).
# - **Execution model:** supports lazy evaluation (build a query plan, then execute efficiently) and query optimization; pandas is mostly eager (does work immediately).
# - **Parallelism:** Polars is designed to use multiple CPU cores by default for many operations; pandas is often single-threaded for typical DataFrame ops.
# - **Memory model:** Polars uses Apache Arrow columnar memory under the hood, which is great for speed and interoperability.

# %% [markdown]
# ### Pandas vs Polars
#
# | Dimension                   | **pandas**                                                         | **Polars**                                                |
# | --------------------------- | ------------------------------------------------------------------ | --------------------------------------------------------- |
# | **Primary language**        | Python (with C/NumPy under the hood)                               | Rust (Python bindings)                                    |
# | **Execution model**         | Eager (operations run immediately)                                 | Eager **and** Lazy (query planning + optimization)        |
# | **Performance**             | Good for small--medium data; can slow down on large groupbys/joins | Often much faster, especially on large datasets           |
# | **Parallelism**             | Limited; many ops are single-threaded                              | Built-in multi-threading by default                       |
# | **Memory format**           | NumPy-based, row-oriented tendencies                               | Apache Arrow, columnar                                    |
# | **Memory efficiency**       | Can be higher overhead, especially with object columns             | Generally more memory-efficient                           |
# | **Data types**              | Flexible; `object` dtype common                                    | Strict, explicit dtypes                                   |
# | **Missing values**          | Uses `NaN`, `None`, nullable dtypes added later                    | Native null support via Arrow                             |
# | **Index**                   | Central concept (powerful but sometimes confusing)                 | No index (explicit columns only)                          |
# | **API style**               | Imperative, step-by-step                                           | Expression-based, declarative                             |
# | **Lazy evaluation**         | ❌ No                                                              | ✅ Yes                                                    |
# | **Query optimization**      | ❌ No                                                              | ✅ Yes                                                    |
# | **Streaming / out-of-core** | Limited                                                            | Supported (especially with lazy mode)                     |
# | **String performance**      | Often slower (`object` strings)                                    | Very fast (Arrow strings)                                 |
# | **Time series support**     | Very mature                                                        | Solid and improving                                       |
# | **Ecosystem support**       | Massive (default for ML, stats, viz)                               | Growing, but smaller                                      |
# | **Learning curve**          | Low (widely taught)                                                | Moderate (different mental model)                         |
# | **Interoperability**        | Native to most Python data tools                                   | Easy conversion to/from pandas                            |
# | **Typical use cases**       | Data exploration, ML prep, teaching, quick analysis                | ETL pipelines, large data, performance-critical workflows |
# | **Maturity**                | Very mature                                                        | Newer but rapidly evolving                                |

# %% [markdown]
# ## Using Polars

# %% [markdown]
# ### Installing Polars
#
# To install polars, use pip in your terminal or command prompt (where your Jupyter environment is set up):
#
# ```
# pip install polars
# ```

# %%
import polars as pl
import datetime as dt

df_polars = pl.DataFrame(
    {
        "developer": [
            "Alice Chen",
            "Brian Patel",
            "Carlos Gomez",
            "Diana Nguyen",
        ],
        "hire_date": [
            dt.date(2019, 6, 1),
            dt.date(2020, 9, 15),
            dt.date(2018, 3, 22),
            dt.date(2021, 1, 10),
        ],
        "weekly_commits": [45, 30, 60, 25],
        "hours_worked": [40, 38, 45, 35],
    }
)

df_polars
# Out:
# shape: (4, 4)
# ┌──────────────┬────────────┬────────────────┬──────────────┐
# │ developer    ┆ hire_date  ┆ weekly_commits ┆ hours_worked │
# │ ---          ┆ ---        ┆ ---            ┆ ---          │
# │ str          ┆ date       ┆ i64            ┆ i64          │
# ╞══════════════╪════════════╪════════════════╪══════════════╡
# │ Alice Chen   ┆ 2019-06-01 ┆ 45             ┆ 40           │
# │ Brian Patel  ┆ 2020-09-15 ┆ 30             ┆ 38           │
# │ Carlos Gomez ┆ 2018-03-22 ┆ 60             ┆ 45           │
# │ Diana Nguyen ┆ 2021-01-10 ┆ 25             ┆ 35           │
# └──────────────┴────────────┴────────────────┴──────────────┘

# %% [markdown]
# Check the type of the `df` object to confirm it's a Polars DataFrame:

# %%
type(df_polars)
# Out:
# polars.dataframe.frame.DataFrame

# %% [markdown]
# ### Comparing Polars and Pandas DataFrames

# %%
import pandas as pd
import datetime as dt

df_pandas = pd.DataFrame(
    {
        "developer": [
            "Alice Chen",
            "Brian Patel",
            "Carlos Gomez",
            "Diana Nguyen",
        ],
        "hire_date": [
            "2019-06-01",
            "2020-09-15",
            "2018-03-22",
            "2021-01-10",
        ],
        "weekly_commits": [45, 30, 60, 25],
        "hours_worked": [40, 38, 45, 35],
    }
)

df_pandas
# Out:
#       developer   hire_date  weekly_commits  hours_worked
# 0    Alice Chen  2019-06-01              45            40
# 1   Brian Patel  2020-09-15              30            38
# 2  Carlos Gomez  2018-03-22              60            45
# 3  Diana Nguyen  2021-01-10              25            35

# %%
type(df_pandas)
# Out:
# pandas.DataFrame

# %% [markdown]
# You'll notice that the Polars DataFrame is of type `polars.dataframe.DataFrame`, while the pandas DataFrame is of type `pandas.core.frame.DataFrame`. Other than that, they look quite similar!
#
# However, Polars offers many modern-API features. For example, Polars supports expressions for data transformations.
#
# For example, here is an expression to calculate the productivity score for each developer based on their number of weekly commits and hours worked:

# %%
result = df_polars.select(
    pl.col("developer"),
    pl.col("hire_date").dt.year().alias("hire_year"),
    (pl.col("weekly_commits") / pl.col("hours_worked")).alias("productivity_score"),
)
result
# Out:
# shape: (4, 3)
# ┌──────────────┬───────────┬────────────────────┐
# │ developer    ┆ hire_year ┆ productivity_score │
# │ ---          ┆ ---       ┆ ---                │
# │ str          ┆ i32       ┆ f64                │
# ╞══════════════╪═══════════╪════════════════════╡
# │ Alice Chen   ┆ 2019      ┆ 1.125              │
# │ Brian Patel  ┆ 2020      ┆ 0.789474           │
# │ Carlos Gomez ┆ 2018      ┆ 1.333333           │
# │ Diana Nguyen ┆ 2021      ┆ 0.714286           │
# └──────────────┴───────────┴────────────────────┘

# %% [markdown]
# You can also add columns to the DataFrame instead of selecting them using `with_columns`:

# %%
result = df_polars.with_columns(
    pl.col("developer"),
    pl.col("hire_date").dt.year().alias("hire_year"),
    (pl.col("weekly_commits") / pl.col("hours_worked")).alias("productivity_score"),
)
result
# Out:
# shape: (4, 6)
# ┌──────────────┬────────────┬────────────────┬──────────────┬───────────┬────────────────────┐
# │ developer    ┆ hire_date  ┆ weekly_commits ┆ hours_worked ┆ hire_year ┆ productivity_score │
# │ ---          ┆ ---        ┆ ---            ┆ ---          ┆ ---       ┆ ---                │
# │ str          ┆ date       ┆ i64            ┆ i64          ┆ i32       ┆ f64                │
# ╞══════════════╪════════════╪════════════════╪══════════════╪═══════════╪════════════════════╡
# │ Alice Chen   ┆ 2019-06-01 ┆ 45             ┆ 40           ┆ 2019      ┆ 1.125              │
# │ Brian Patel  ┆ 2020-09-15 ┆ 30             ┆ 38           ┆ 2020      ┆ 0.789474           │
# │ Carlos Gomez ┆ 2018-03-22 ┆ 60             ┆ 45           ┆ 2018      ┆ 1.333333           │
# │ Diana Nguyen ┆ 2021-01-10 ┆ 25             ┆ 35           ┆ 2021      ┆ 0.714286           │
# └──────────────┴────────────┴────────────────┴──────────────┴───────────┴────────────────────┘

# %% [markdown]
# ### Filtering
#
# Filtering in Polars can be done using expressions as well. For example, to filter developers with a productivity score greater than 1:

# %%
result = df_polars.filter((pl.col("weekly_commits") / pl.col("hours_worked")) > 1)
result
# Out:
# shape: (2, 4)
# ┌──────────────┬────────────┬────────────────┬──────────────┐
# │ developer    ┆ hire_date  ┆ weekly_commits ┆ hours_worked │
# │ ---          ┆ ---        ┆ ---            ┆ ---          │
# │ str          ┆ date       ┆ i64            ┆ i64          │
# ╞══════════════╪════════════╪════════════════╪══════════════╡
# │ Alice Chen   ┆ 2019-06-01 ┆ 45             ┆ 40           │
# │ Carlos Gomez ┆ 2018-03-22 ┆ 60             ┆ 45           │
# └──────────────┴────────────┴────────────────┴──────────────┘

# %% [markdown]
# You can also provide multiple expressions as separate parameters, which is much more convenient than having to use bitwise operators (`&`, `|`) as in pandas.

# %%
result = df_polars.filter(
    pl.col("hire_date").is_between(dt.date(2018, 1, 1), dt.date(2019, 12, 31)),
    pl.col("hours_worked") >= 40,
)
result
# Out:
# shape: (2, 4)
# ┌──────────────┬────────────┬────────────────┬──────────────┐
# │ developer    ┆ hire_date  ┆ weekly_commits ┆ hours_worked │
# │ ---          ┆ ---        ┆ ---            ┆ ---          │
# │ str          ┆ date       ┆ i64            ┆ i64          │
# ╞══════════════╪════════════╪════════════════╪══════════════╡
# │ Alice Chen   ┆ 2019-06-01 ┆ 45             ┆ 40           │
# │ Carlos Gomez ┆ 2018-03-22 ┆ 60             ┆ 45           │
# └──────────────┴────────────┴────────────────┴──────────────┘

# %% [markdown]
# ## More Examples
#
# The cells below show a handful of additional Polars patterns you will use again
# and again on the credit-card dataset.
#
# ### Add a Team Column
#
# Most of the new examples need a categorical column to group by, so let's
# extend the developer DataFrame with a `team` column.

# %%
df_devs = df_polars.with_columns(
    pl.Series("team", ["Platform", "Search", "Platform", "Billing"])
)
df_devs
# Out:
# shape: (4, 5)
# ┌──────────────┬────────────┬────────────────┬──────────────┬──────────┐
# │ developer    ┆ hire_date  ┆ weekly_commits ┆ hours_worked ┆ team     │
# │ ---          ┆ ---        ┆ ---            ┆ ---          ┆ ---      │
# │ str          ┆ date       ┆ i64            ┆ i64          ┆ str      │
# ╞══════════════╪════════════╪════════════════╪══════════════╪══════════╡
# │ Alice Chen   ┆ 2019-06-01 ┆ 45             ┆ 40           ┆ Platform │
# │ Brian Patel  ┆ 2020-09-15 ┆ 30             ┆ 38           ┆ Search   │
# │ Carlos Gomez ┆ 2018-03-22 ┆ 60             ┆ 45           ┆ Platform │
# │ Diana Nguyen ┆ 2021-01-10 ┆ 25             ┆ 35           ┆ Billing  │
# └──────────────┴────────────┴────────────────┴──────────────┴──────────┘

# %% [markdown]
# ### Group By and Aggregate
#
# Like SQL's `GROUP BY`, Polars' `.group_by()` lets you compute summary statistics
# per category. Multiple aggregations are listed inside `.agg()` and each one
# returns its own column.

# %%
summary = (
    df_devs
    .group_by("team")
    .agg(
        pl.len().alias("n_developers"),
        pl.col("hours_worked").mean().round(1).alias("avg_hours"),
        pl.col("weekly_commits").sum().alias("total_commits"),
    )
    .sort("total_commits", descending=True)
)
summary
# Out:
# shape: (3, 4)
# ┌──────────┬──────────────┬───────────┬───────────────┐
# │ team     ┆ n_developers ┆ avg_hours ┆ total_commits │
# │ ---      ┆ ---          ┆ ---       ┆ ---           │
# │ str      ┆ u32          ┆ f64       ┆ i64           │
# ╞══════════╪══════════════╪═══════════╪═══════════════╡
# │ Platform ┆ 2            ┆ 42.5      ┆ 105           │
# │ Search   ┆ 1            ┆ 38.0      ┆ 30            │
# │ Billing  ┆ 1            ┆ 35.0      ┆ 25            │
# └──────────┴──────────────┴───────────┴───────────────┘

# %% [markdown]
# ### Add Computed Columns with `with_columns`
#
# `.with_columns()` is the Polars equivalent of pandas `df["x"] = ...`. It is
# chainable and returns a new DataFrame, so the original is untouched.

# %%
enriched = df_devs.with_columns(
    (pl.col("weekly_commits") / pl.col("hours_worked")).round(2).alias("commits_per_hour"),
    pl.when(pl.col("hours_worked") >= 40)
      .then(pl.lit("Full time"))
      .otherwise(pl.lit("Part time"))
      .alias("status"),
)
enriched
# Out:
# shape: (4, 7)
# ┌──────────────┬────────────┬────────────────┬──────────────┬──────────┬───────────────┬───────────┐
# │ developer    ┆ hire_date  ┆ weekly_commits ┆ hours_worked ┆ team     ┆ commits_per_h ┆ status    │
# │ ---          ┆ ---        ┆ ---            ┆ ---          ┆ ---      ┆ our           ┆ ---       │
# │ str          ┆ date       ┆ i64            ┆ i64          ┆ str      ┆ ---           ┆ str       │
# │              ┆            ┆                ┆              ┆          ┆ f64           ┆           │
# ╞══════════════╪════════════╪════════════════╪══════════════╪══════════╪═══════════════╪═══════════╡
# │ Alice Chen   ┆ 2019-06-01 ┆ 45             ┆ 40           ┆ Platform ┆ 1.12          ┆ Full time │
# │ Brian Patel  ┆ 2020-09-15 ┆ 30             ┆ 38           ┆ Search   ┆ 0.79          ┆ Part time │
# │ Carlos Gomez ┆ 2018-03-22 ┆ 60             ┆ 45           ┆ Platform ┆ 1.33          ┆ Full time │
# │ Diana Nguyen ┆ 2021-01-10 ┆ 25             ┆ 35           ┆ Billing  ┆ 0.71          ┆ Part time │
# └──────────────┴────────────┴────────────────┴──────────────┴──────────┴───────────────┴───────────┘

# %% [markdown]
# :::{tip} Why `pl.col()` instead of `df["col"]`?
# The `pl.col(...)` expression is **lazy** — it describes the operation without
# executing it. Polars then optimises the whole chain (predicate pushdown, common
# subexpression elimination, parallelism) before running it. This is the single
# biggest performance difference between Polars and pandas.
# :::

# %% [markdown]
# ### Lazy Evaluation with `LazyFrame`
#
# For larger-than-memory data, swap `pl.read_csv` for `pl.scan_csv`. Polars then
# builds a query plan and only executes it when you call `.collect()`.

# %%
# Convert our existing DataFrame to a LazyFrame just to demonstrate the API.
lazy_query = (
    df_devs.lazy()
    .filter(pl.col("hours_worked") >= 35)
    .group_by("team")
    .agg(pl.col("weekly_commits").mean().alias("avg_commits"))
    .sort("avg_commits", descending=True)
)

# .explain() shows the optimised plan; .collect() runs it.
print(lazy_query.explain())
lazy_query.collect()
# Out:
# SORT BY [descending: [true]] [col("avg_commits")]
#   AGGREGATE[maintain_order: false]
#     [col("weekly_commits").mean().alias("avg_commits")] BY [col("team")]
#     FROM
#     simple π 2/2 ["weekly_commits", "team"]
#       FILTER [(col("hours_worked")) >= (35)]
#       FROM
#         DF ["developer", "hire_date", "weekly_commits", "hours_worked", ...]; PROJECT["weekly_commits", "team", "hours_worked"] 3/5 COLUMNS
# shape: (3, 2)
# ┌──────────┬─────────────┐
# │ team     ┆ avg_commits │
# │ ---      ┆ ---         │
# │ str      ┆ f64         │
# ╞══════════╪═════════════╡
# │ Platform ┆ 52.5        │
# │ Search   ┆ 30.0        │
# │ Billing  ┆ 25.0        │
# └──────────┴─────────────┘

# %% [markdown]
# ### Joining DataFrames
#
# Polars supports the usual `inner`, `left`, `outer`, `semi`, `anti`, and `cross`
# join types. The syntax is `left.join(right, on=..., how=...)`.

# %%
team_metadata = pl.DataFrame({
    "team":      ["Platform", "Search", "Billing", "Analytics"],
    "office":    ["NYC", "Berlin", "NYC", "Remote"],
    "tech_lead": ["Maya R.", "Lin H.", "Omar K.", "Priya S."],
})

df_devs.join(team_metadata, on="team", how="left")
# Out:
# shape: (4, 7)
# ┌──────────────┬────────────┬────────────────┬──────────────┬──────────┬────────┬───────────┐
# │ developer    ┆ hire_date  ┆ weekly_commits ┆ hours_worked ┆ team     ┆ office ┆ tech_lead │
# │ ---          ┆ ---        ┆ ---            ┆ ---          ┆ ---      ┆ ---    ┆ ---       │
# │ str          ┆ date       ┆ i64            ┆ i64          ┆ str      ┆ str    ┆ str       │
# ╞══════════════╪════════════╪════════════════╪══════════════╪══════════╪════════╪═══════════╡
# │ Alice Chen   ┆ 2019-06-01 ┆ 45             ┆ 40           ┆ Platform ┆ NYC    ┆ Maya R.   │
# │ Brian Patel  ┆ 2020-09-15 ┆ 30             ┆ 38           ┆ Search   ┆ Berlin ┆ Lin H.    │
# │ Carlos Gomez ┆ 2018-03-22 ┆ 60             ┆ 45           ┆ Platform ┆ NYC    ┆ Maya R.   │
# │ Diana Nguyen ┆ 2021-01-10 ┆ 25             ┆ 35           ┆ Billing  ┆ NYC    ┆ Omar K.   │
# └──────────────┴────────────┴────────────────┴──────────────┴──────────┴────────┴───────────┘

# %% [markdown]
# :::{seealso} Joins are *much* faster than in pandas
# On large transactional datasets, Polars joins routinely run **5–20×** faster
# than the equivalent pandas merge thanks to its hash join implementation and
# multi-threaded execution. We will rely on this when we join transactions to
# merchant metadata in the analysis notebook.
# :::
