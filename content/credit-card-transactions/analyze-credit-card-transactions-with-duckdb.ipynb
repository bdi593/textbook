# %% [markdown]
# # Using DuckDB for Data Analysis
#
# ## Overview
#
# In this exercise, you will walk through the previous data preprocessing workflow using DuckDB.
#
# The goal is to replicate the same steps we performed in polars, but this time using SQL queries in DuckDB. This will give you a chance to see how the same transformations can be expressed in SQL and how DuckDB handles data manipulation.
#
# You will learn how to:
#
# - Load and inspect data
# - Identify and handle missing values
# - Clean and standardize columns
# - Perform basic transformations
# - Verify the final dataset

# %% [markdown]
# ## Import Libraries

# %%
import duckdb

# %% [markdown]
# ## Read the Input Parquet File
#
# First, download the `credit_card_transactions-ibm_v2.parquet` file from [this GitHub link](https://github.com/bdi593/datasets/raw/refs/heads/main/credit-card-transactions-ibm/credit_card_transactions-ibm_v2.parquet?download=) and place it in the same folder as your Jupyter notebook.
#
# The file is about 250 MB, which is about 9 times smaller than the original CSV file, making it much faster to read and process.
#
# :::{tip} Why is Parquet smaller than CSV?
#
# Recall that Parquet is a columnar storage format that uses efficient compression and encoding techniques, while CSV is a plain text format that stores data in a row-wise manner without any compression. This is why Parquet files are often significantly smaller than their CSV counterparts.
#
# You can also compress CSV files using different algorithms (like gzip or bzip2), but even then, Parquet often achieves better compression ratios due to its columnar nature and optimized encoding.
#
# :::

# %% [markdown]
# ### `duckdb.connect()`
#
# The `duckdb.connect()` function creates a connection to a DuckDB database. If you don't specify a database name, it creates an in-memory database that exists only for the duration of the connection. This is useful for ad-hoc analysis and temporary data manipulation without needing to manage a persistent database file.

# %%
con = duckdb.connect()

con.execute(
    """
CREATE OR REPLACE VIEW transactions AS
SELECT *
FROM read_parquet('credit_card_transactions-ibm_v2.parquet');
"""
)

# Peek (like df.head())
con.sql("SELECT * FROM transactions LIMIT 5").df()
# Out:
#    User  Card  Amount            Datetime           Use Chip  \
# 0     0     0  134.09 2002-09-01 06:21:00  Swipe Transaction
# 1     0     0   38.48 2002-09-01 06:42:00  Swipe Transaction
# 2     0     0  120.34 2002-09-02 06:22:00  Swipe Transaction
# 3     0     0  128.95 2002-09-02 17:45:00  Swipe Transaction
# 4     0     0  104.71 2002-09-03 06:23:00  Swipe Transaction
#
#          Merchant Name  Merchant City Merchant State      Zip   MCC Errors?  \
# 0  3527213246127876953       La Verne             CA  91750.0  5300    None
# 1  -727612092139916043  Monterey Park             CA  91754.0  5411    None
# 2  -727612092139916043  Monterey Park             CA  91754.0  5411    None
# 3  3414527459579106770  Monterey Park             CA  91754.0  5651    None
# 4  5817218446178736267       La Verne             CA  91750.0  5912    None
#
#   Is Fraud?
# 0        No
# 1        No
# 2        No
# 3        No
# 4        No

# %% [markdown]
# :::{tip} DuckDB's `.df()` Method
#
# The `.df()` method in DuckDB is used to convert a DuckDB query result into a Pandas DataFrame. This allows you to easily manipulate and analyze the data using Pandas' powerful data handling capabilities after performing SQL queries in DuckDB.
#
# However, you should be cautious when using `.df()` with large datasets, as it will load the entire result set into memory. If the dataset is too large to fit in memory, it can lead to performance issues or crashes. Always consider the size of your data and the available memory before using `.df()`.
#
# To avoid loading large dataset into memory, consider (1) using the `LIMIT` clause in your SQL queries to reduce the amount of data being loaded when testing or exploring the data, and (2) aggregating or filtering the data in SQL to reduce the result set size before converting it to a DataFrame.
#
# :::

# %% [markdown]
# ## Exploratory Data Analysis (EDA)

# %% [markdown]
# ### Describe Schema
#
# To understand the structure of the dataset, we can use the `DESCRIBE` command to get information about the columns, their data types, and whether they contain null values.

# %%
con.sql("DESCRIBE transactions;").df()
# Out:
#        column_name column_type null   key default extra
# 0             User      BIGINT  YES  None    None  None
# 1             Card      BIGINT  YES  None    None  None
# 2           Amount      DOUBLE  YES  None    None  None
# 3         Datetime   TIMESTAMP  YES  None    None  None
# 4         Use Chip     VARCHAR  YES  None    None  None
# 5    Merchant Name      BIGINT  YES  None    None  None
# 6    Merchant City     VARCHAR  YES  None    None  None
# 7   Merchant State     VARCHAR  YES  None    None  None
# 8              Zip      DOUBLE  YES  None    None  None
# 9              MCC      BIGINT  YES  None    None  None
# 10         Errors?     VARCHAR  YES  None    None  None
# 11       Is Fraud?     VARCHAR  YES  None    None  None

# %% [markdown]
# If you're familiar with the `PRAGMA` introspection command from SQLite or another engine, you can also use `PRAGMA table_info('transactions');` to get similar information about the columns in the `transactions` table.

# %%
con.sql("PRAGMA table_info('transactions');").df()
# Out:
#     cid            name       type  notnull dflt_value     pk
# 0     0            User     BIGINT    False       None  False
# 1     1            Card     BIGINT    False       None  False
# 2     2          Amount     DOUBLE    False       None  False
# 3     3        Datetime  TIMESTAMP    False       None  False
# 4     4        Use Chip    VARCHAR    False       None  False
# 5     5   Merchant Name     BIGINT    False       None  False
# 6     6   Merchant City    VARCHAR    False       None  False
# 7     7  Merchant State    VARCHAR    False       None  False
# 8     8             Zip     DOUBLE    False       None  False
# 9     9             MCC     BIGINT    False       None  False
# 10   10         Errors?    VARCHAR    False       None  False
# 11   11       Is Fraud?    VARCHAR    False       None  False

# %% [markdown]
# Note that the `Datetime` column is `TIMESTAMP` type, which means it contains both date and time information. The `Amount` column is `DOUBLE`, which is a floating-point number, and the `Merchant Name` column is `BIGINT`, which were encoded as integers to avoid confusion with real merchant names. The `Errors?` and `Is Fraud?` columns use `VARCHAR` type, which is a variable-length string.

# %%
con.sql('SELECT DISTINCT("Is Fraud?") FROM transactions;').df()
# Out:
#   Is Fraud?
# 0        No
# 1       Yes

# %% [markdown]
# ### Convert `"Is Fraud?"` column to a boolean
#
# The `"Is Fraud?"` column currently contains string values ("True" and "False"). We can convert this column to a boolean type for easier analysis.

# %%
con.sql(
    """
CREATE OR REPLACE VIEW transactions_with_fraud_flag AS
SELECT
  * EXCLUDE ("Is Fraud?"),
  CASE
    WHEN "Is Fraud?" = 'Yes' THEN TRUE
    WHEN "Is Fraud?" = 'No'  THEN FALSE
    ELSE NULL
  END AS "Is Fraud?"
FROM transactions;
"""
)

# %%
con.sql(
    """
SELECT *
FROM transactions_with_fraud_flag
LIMIT 5;
"""
).df()
# Out:
#    User  Card  Amount            Datetime           Use Chip  \
# 0     0     0  134.09 2002-09-01 06:21:00  Swipe Transaction
# 1     0     0   38.48 2002-09-01 06:42:00  Swipe Transaction
# 2     0     0  120.34 2002-09-02 06:22:00  Swipe Transaction
# 3     0     0  128.95 2002-09-02 17:45:00  Swipe Transaction
# 4     0     0  104.71 2002-09-03 06:23:00  Swipe Transaction
#
#          Merchant Name  Merchant City Merchant State      Zip   MCC Errors?  \
# 0  3527213246127876953       La Verne             CA  91750.0  5300    None
# 1  -727612092139916043  Monterey Park             CA  91754.0  5411    None
# 2  -727612092139916043  Monterey Park             CA  91754.0  5411    None
# 3  3414527459579106770  Monterey Park             CA  91754.0  5651    None
# 4  5817218446178736267       La Verne             CA  91750.0  5912    None
#
#    Is Fraud?
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False

# %% [markdown]
# You can verify that the `"Is Fraud?"` column is now a boolean type using the `DESCRIBE` command again.

# %%
con.sql("DESCRIBE transactions_with_fraud_flag;").df()
# Out:
#        column_name column_type null   key default extra
# 0             User      BIGINT  YES  None    None  None
# 1             Card      BIGINT  YES  None    None  None
# 2           Amount      DOUBLE  YES  None    None  None
# 3         Datetime   TIMESTAMP  YES  None    None  None
# 4         Use Chip     VARCHAR  YES  None    None  None
# 5    Merchant Name      BIGINT  YES  None    None  None
# 6    Merchant City     VARCHAR  YES  None    None  None
# 7   Merchant State     VARCHAR  YES  None    None  None
# 8              Zip      DOUBLE  YES  None    None  None
# 9              MCC      BIGINT  YES  None    None  None
# 10         Errors?     VARCHAR  YES  None    None  None
# 11       Is Fraud?     BOOLEAN  YES  None    None  None

# %% [markdown]
# ### Payment method frequency analysis
#
# The code below provides a high-level summary of the payment methods used across your credit card dataset. The `.value_counts()` method performs a frequency analysis on the `"Use Chip"` column, identifying every unique entry (Chip, Online, and Swipe transactions).

# %%
con.sql(
    """
SELECT
  "Use Chip",
  COUNT(*) AS count
FROM transactions
GROUP BY "Use Chip"
ORDER BY count DESC;
        """
)
# Out:
# ┌────────────────────┬──────────┐
# │      Use Chip      │  count   │
# │      varchar       │  int64   │
# ├────────────────────┼──────────┤
# │ Swipe Transaction  │ 15386082 │
# │ Chip Transaction   │  6287598 │
# │ Online Transaction │  2713220 │
# └────────────────────┴──────────┘

# %% [markdown]
# Looking at the numbers, you can see that Swipe Transactions are the dominant payment method in this dataset with over 15 million entries, followed by Chip Transactions at roughly 6.2 million. This breakdown is essential for understanding consumer behavior or detecting potential fraud patterns, as certain types of transactions (like "Online" vs. "Swipe") carry different risk profiles.

# %% [markdown]
# ### Fraud distribution analysis
#
# The code below shows the frequency of the `"Is Fraud?"` column to determine the distribution of legitimate versus fraudulent transactions within your dataset.

# %%
con.sql(
    """
SELECT
  "Is Fraud?",
  COUNT(*) AS count
FROM transactions
GROUP BY "Is Fraud?"
ORDER BY count DESC;
        """
)
# Out:
# ┌───────────┬──────────┐
# │ Is Fraud? │  count   │
# │  varchar  │  int64   │
# ├───────────┼──────────┤
# │ No        │ 24357143 │
# │ Yes       │    29757 │
# └───────────┴──────────┘

# %% [markdown]
# The data reveals that the overwhelming majority of transactions - over 24.3 million - are flagged as "No", while only 29,757 are flagged as "Yes". While the fraudulent cases represent a very small fraction of the total volume (roughly 0.12%), identifying this minority is the primary goal of most credit card analytics. Understanding this ratio is a critical first step before building a machine learning model, as it tells you that you'll need specialized techniques, like oversampling or specific loss functions, to account for the rarity of fraud.

# %% [markdown]
# ### Flag suspicious transactions based on amount
#
# The code below performs feature engineering by creating three new boolean (`True`/`False`) indicators based on specific transaction characteristics.
#
# The `AS` keyword is used to assign a name to each new column, making it easier to reference them in subsequent queries.

# %%
con.sql(
    """
SELECT
  *,
  "Amount" < 0 AS is_refund,
  "Amount" > 500 AS large_txn,
  "Use Chip" = 'Online Transaction' AS is_online
FROM transactions
LIMIT 10;
"""
).df()
# Out:
#    User  Card  Amount            Datetime           Use Chip  \
# 0     0     0  134.09 2002-09-01 06:21:00  Swipe Transaction
# 1     0     0   38.48 2002-09-01 06:42:00  Swipe Transaction
# 2     0     0  120.34 2002-09-02 06:22:00  Swipe Transaction
# 3     0     0  128.95 2002-09-02 17:45:00  Swipe Transaction
# 4     0     0  104.71 2002-09-03 06:23:00  Swipe Transaction
# 5     0     0   86.19 2002-09-03 13:53:00  Swipe Transaction
# 6     0     0   93.84 2002-09-04 05:51:00  Swipe Transaction
# 7     0     0  123.50 2002-09-04 06:09:00  Swipe Transaction
# 8     0     0   61.72 2002-09-05 06:14:00  Swipe Transaction
# 9     0     0   57.10 2002-09-05 09:35:00  Swipe Transaction
#
#          Merchant Name  Merchant City Merchant State      Zip   MCC Errors?  \
# 0  3527213246127876953       La Verne             CA  91750.0  5300    None
# 1  -727612092139916043  Monterey Park             CA  91754.0  5411    None
# 2  -727612092139916043  Monterey Park             CA  91754.0  5411    None
# 3  3414527459579106770  Monterey Park             CA  91754.0  5651    None
# 4  5817218446178736267       La Verne             CA  91750.0  5912    None
# 5 -7146670748125200898  Monterey Park             CA  91755.0  5970    None
# 6  -727612092139916043  Monterey Park             CA  91754.0  5411    None
# 7  -727612092139916043  Monterey Park             CA  91754.0  5411    None
# 8  -727612092139916043  Monterey Park             CA  91754.0  5411    None
# 9  4055257078481058705       La Verne             CA  91750.0  7538    None
#
#   Is Fraud?  is_refund  large_txn  is_online
# 0        No      False      False      False
# 1        No      False      False      False
# 2        No      False      False      False
# 3        No      False      False      False
# 4        No      False      False      False
# 5        No      False      False      False
# 6        No      False      False      False
# 7        No      False      False      False
# 8        No      False      False      False
# 9        No      False      False      False

# %% [markdown]
# These "flag" columns can be useful for both exploratory analysis and machine learning. Instead of writing complex filters repeatedly, you can now quickly segment your data. For example, to see if "large transactions" are more likely to be "fraudulent" or to calculate the total volume of "online" versus in-person sales. This step transforms raw data into behavioral features, providing the model or the analyst with clear, binary signals that highlight high-interest events within the transaction stream.

# %% [markdown]
# ### Filter rows based on conditions
#
# You can also apply a filter to isolate a very specific subset of your data: online refunds. The `WHERE` clause in the SQL query allows you to specify multiple conditions that must be met for a row to be included in the result set. In this case, we are filtering for transactions where the `"Amount"` is less than 0 (indicating a refund) and the `"Use Chip"` column indicates an "Online Transaction".

# %%
con.sql(
    """
SELECT *
FROM transactions
WHERE
  "Amount" < 0
  AND "Use Chip" = 'Online Transaction'
LIMIT 10;
"""
).df()
# Out:
#    User  Card  Amount            Datetime            Use Chip  \
# 0     0     0  -100.0 2004-12-10 20:45:00  Online Transaction
# 1     0     0  -393.0 2010-10-08 18:00:00  Online Transaction
# 2     0     0  -443.0 2011-12-19 12:50:00  Online Transaction
# 3     0     0  -473.0 2015-11-20 07:42:00  Online Transaction
# 4     0     2  -461.0 2017-02-21 08:03:00  Online Transaction
# 5     0     3  -140.0 2003-02-27 23:24:00  Online Transaction
# 6     0     3  -246.0 2005-01-22 12:59:00  Online Transaction
# 7     0     3  -450.0 2005-06-30 06:36:00  Online Transaction
# 8     0     3  -351.0 2008-03-09 06:32:00  Online Transaction
# 9     0     3  -386.0 2013-01-13 21:45:00  Online Transaction
#
#          Merchant Name Merchant City Merchant State  Zip   MCC Errors?  \
# 0  7501849281341469857        ONLINE           None  NaN  4722    None
# 1   333722291367506728        ONLINE           None  NaN  4722    None
# 2   333722291367506728        ONLINE           None  NaN  4722    None
# 3 -8566951830324093739        ONLINE           None  NaN  3640    None
# 4  7501849281341469857        ONLINE           None  NaN  4722    None
# 5 -6796080605569913348        ONLINE           None  NaN  4722    None
# 6  3694722044710185708        ONLINE           None  NaN  4722    None
# 7 -6796080605569913348        ONLINE           None  NaN  4722    None
# 8  7501849281341469857        ONLINE           None  NaN  4722    None
# 9  7501849281341469857        ONLINE           None  NaN  4722    None
#
#   Is Fraud?
# 0        No
# 1        No
# 2        No
# 3       Yes
# 4        No
# 5        No
# 6        No
# 7        No
# 8        No
# 9        No

# %% [markdown]
# ### Per-user aggregation
#
# The code below performs a user-level aggregation, collapsing millions of individual transaction records into a concise summary of spending behavior for each unique customer. By using the `GROUP BY` clause, you are instructing DuckDB to organize the data into buckets based on the individual user ID. The `SELECT` statement with aggregate functions then calculates three key metrics for each bucket:
#
# 1. the total volume of money spent,
# 2. the average cost per purchase, and
# 3. the total number of transactions

# %%
user_stats = con.sql(
    """
SELECT
  "User",
  SUM("Amount") AS total_spent,
  AVG("Amount") AS average_amount,
  COUNT(*)      AS num_transactions
FROM transactions
GROUP BY "User";
"""
).df()

user_stats.head()
# Out:
#    User  total_spent  average_amount  num_transactions
# 0     0   1622991.69       81.299989             19963
# 1     1    723491.89       81.118050              8919
# 2     2   1475933.36       35.159687             41978
# 3     3   1186497.51      117.277603             10117
# 4     4   1798790.91       97.011698             18542

# %% [markdown]
# Rolling / window features (SQL-like mental model):

# %% [markdown]
# ### 10 most recent transactions rolling sum
#
# You can also compute rolling aggregates to capture recent behavior. The code below calculates a rolling sum of the `"Amount"` column over the last 10 transactions for each user.

# %%
con.sql(
    """
SELECT
  *,
  SUM("Amount") OVER (
    PARTITION BY "User"
    ORDER BY "Datetime"
    ROWS BETWEEN 9 PRECEDING AND CURRENT ROW
  ) AS rolling_amount_sum_10
FROM transactions
ORDER BY "User", "Datetime"
LIMIT 100;
"""
).df()
# Out:
# FloatProgress(value=0.0, layout=Layout(width='auto'), style=ProgressStyle(bar_color='black'))
#     User  Card  Amount            Datetime            Use Chip  \
# 0      0     0  134.09 2002-09-01 06:21:00   Swipe Transaction
# 1      0     0   38.48 2002-09-01 06:42:00   Swipe Transaction
# 2      0     0  120.34 2002-09-02 06:22:00   Swipe Transaction
# 3      0     0  128.95 2002-09-02 17:45:00   Swipe Transaction
# 4      0     0  104.71 2002-09-03 06:23:00   Swipe Transaction
# ..   ...   ...     ...                 ...                 ...
# 95     0     0   36.44 2002-10-03 06:50:00   Swipe Transaction
# 96     0     0  114.87 2002-10-04 06:20:00   Swipe Transaction
# 97     0     0   53.13 2002-10-05 09:34:00   Swipe Transaction
# 98     0     0   16.87 2002-10-05 10:38:00   Swipe Transaction
# 99     0     0  139.39 2002-10-06 06:14:00  Online Transaction
#
#           Merchant Name  Merchant City Merchant State      Zip   MCC Errors?  \
# 0   3527213246127876953       La Verne             CA  91750.0  5300     NaN
# 1   -727612092139916043  Monterey Park             CA  91754.0  5411     NaN
# 2   -727612092139916043  Monterey Park             CA  91754.0  5411     NaN
# 3   3414527459579106770  Monterey Park             CA  91754.0  5651     NaN
# 4   5817218446178736267       La Verne             CA  91750.0  5912     NaN
# ..                  ...            ...            ...      ...   ...     ...
# 95 -5475680618560174533  Monterey Park             CA  91755.0  5942     NaN
# 96  3527213246127876953       La Verne             CA  91750.0  5300     NaN
# 97 -3345936507911876459       La Verne             CA  91750.0  7538     NaN
# 98  9137769173591184401       La Verne             CA  91750.0  7210     NaN
# 99 -7421093378627544099         ONLINE            NaN      NaN  5311     NaN
#
#    Is Fraud?  rolling_amount_sum_10
# 0         No                 134.09
# 1         No                 172.57
# 2         No                 292.91
# 3         No                 421.86
# 4         No                 526.57
# ..       ...                    ...
# 95        No                 639.98
# 96        No                 716.72
# 97        No                 758.55
# 98        No                 695.37
# 99        No                 715.03
#
# [100 rows x 13 columns]

# %% [markdown]
# ## Additional Analyses
#
# The same business questions we explored in the Polars notebook can be
# expressed concisely in SQL. The queries below extend the preprocessing
# pipeline with a few more analyses you would routinely build for a fraud or
# marketing team.

# %% [markdown]
# ### Top Merchants by Total Spend
#
# A textbook `GROUP BY ... ORDER BY` query.

# %%
con.sql(
    """
SELECT
    "Merchant Name",
    ROUND(SUM("Amount"), 2)  AS total_spend,
    COUNT(*)                 AS n_transactions,
    ROUND(AVG("Amount"), 2)  AS avg_ticket
FROM transactions
GROUP BY "Merchant Name"
ORDER BY total_spend DESC
LIMIT 10
"""
)
# Out:
# ┌──────────────────────┬──────────────┬────────────────┬────────────┐
# │    Merchant Name     │ total_spend  │ n_transactions │ avg_ticket │
# │        int64         │    double    │     int64      │   double   │
# ├──────────────────────┼──────────────┼────────────────┼────────────┤
# │ -4282466774399734331 │ 101787066.82 │        1129061 │      90.15 │
# │  1913477460590765860 │  35349420.24 │         562158 │      62.88 │
# │ -2088492411650162548 │   25554655.3 │         720615 │      35.46 │
# │  2027553650310142703 │   22045032.2 │        1028485 │      21.43 │
# │  4241336128694185533 │  19182882.88 │         173206 │     110.75 │
# │ -5467922351692495955 │  17096508.71 │         374905 │       45.6 │
# │  1799189980464955940 │  16417797.54 │        1130230 │      14.53 │
# │ -5162038175624867091 │  14271024.91 │         676694 │      21.09 │
# │    97032797689821735 │  14245596.06 │         541794 │      26.29 │
# │  4722913068560264812 │   12182126.2 │         476913 │      25.54 │
# ├──────────────────────┴──────────────┴────────────────┴────────────┤
# │ 10 rows                                                 4 columns │
# └───────────────────────────────────────────────────────────────────┘

# %% [markdown]
# ### Hourly Transaction Pattern
#
# DuckDB's `EXTRACT(HOUR FROM ...)` returns the hour of day from a timestamp.
# This is the SQL counterpart of the Polars `.dt.hour()` expression.

# %%
con.sql(
    """
SELECT
    EXTRACT(HOUR FROM "Datetime") AS hour,
    COUNT(*)                      AS n_transactions,
    ROUND(SUM("Amount"), 2)       AS total_spend
FROM transactions
GROUP BY hour
ORDER BY hour
"""
)
# Out:
# ┌───────┬────────────────┬─────────────┐
# │ hour  │ n_transactions │ total_spend │
# │ int64 │     int64      │   double    │
# ├───────┼────────────────┼─────────────┤
# │     0 │         235608 │ 12522029.46 │
# │     1 │         213411 │ 11972821.86 │
# │     2 │         214075 │ 10928316.34 │
# │     3 │         183370 │   9692236.4 │
# │     4 │         203550 │ 11400974.34 │
# │     5 │         321588 │ 14832093.09 │
# │     6 │        1347058 │ 47235870.39 │
# │     7 │        1644618 │ 55614757.51 │
# │     8 │        1616851 │ 57074988.17 │
# │     9 │        1598928 │ 56437859.53 │
# │     · │           ·    │      ·      │
# │     · │           ·    │      ·      │
# │     · │           ·    │      ·      │
# │    14 │        1632864 │ 79208117.17 │
# │    15 │        1559102 │ 73500565.53 │
# │    16 │        1589776 │ 75404518.53 │
# │    17 │         900509 │ 44767771.57 │
# │    18 │         837841 │ 43253314.94 │
# │    19 │         847344 │ 43777797.02 │
# │    20 │         793351 │ 41597961.28 │
# │    21 │         765024 │ 38862723.87 │
# │    22 │         759960 │ 38450353.42 │
# │    23 │         300464 │ 17253569.29 │
# ├───────┴────────────────┴─────────────┤
# │ 24 rows (20 shown)         3 columns │
# └──────────────────────────────────────┘

# %% [markdown]
# ### Fraud Rate by Use-Chip Category
#
# `AVG(CASE WHEN ... THEN 1 ELSE 0 END)` is the SQL idiom for "share of rows
# matching a condition". It is exactly equivalent to the Polars
# `pl.col("is_fraud").mean()` expression.

# %%
con.sql(
    """
SELECT
    "Use Chip",
    COUNT(*)                                                      AS n_transactions,
    SUM(CASE WHEN "Is Fraud?" = 'Yes' THEN 1 ELSE 0 END)          AS n_fraud,
    ROUND(AVG(CASE WHEN "Is Fraud?" = 'Yes' THEN 1 ELSE 0 END) * 100, 3) AS fraud_rate_pct
FROM transactions
GROUP BY "Use Chip"
ORDER BY fraud_rate_pct DESC
"""
)
# Out:
# ┌────────────────────┬────────────────┬─────────┬────────────────┐
# │      Use Chip      │ n_transactions │ n_fraud │ fraud_rate_pct │
# │      varchar       │     int64      │ int128  │     double     │
# ├────────────────────┼────────────────┼─────────┼────────────────┤
# │ Online Transaction │        2713220 │   18349 │          0.676 │
# │ Chip Transaction   │        6287598 │    4836 │          0.077 │
# │ Swipe Transaction  │       15386082 │    6572 │          0.043 │
# └────────────────────┴────────────────┴─────────┴────────────────┘

# %% [markdown]
# ### Time Since Previous Transaction (per User)
#
# `LAG()` is the canonical window function for "give me the previous row's
# value". Pair it with `PARTITION BY User ORDER BY Datetime` and you get exactly
# the same per-user shift we computed in Polars.

# %%
con.sql(
    """
SELECT
    "User",
    "Datetime",
    "Amount",
    EXTRACT(EPOCH FROM
        "Datetime" - LAG("Datetime") OVER (PARTITION BY "User" ORDER BY "Datetime")
    ) AS seconds_since_last_txn
FROM transactions
ORDER BY "User", "Datetime"
LIMIT 15
"""
)
# Out:
# ┌───────┬─────────────────────┬────────┬────────────────────────┐
# │ User  │      Datetime       │ Amount │ seconds_since_last_txn │
# │ int64 │      timestamp      │ double │         double         │
# ├───────┼─────────────────────┼────────┼────────────────────────┤
# │     0 │ 2002-09-01 06:21:00 │ 134.09 │                   NULL │
# │     0 │ 2002-09-01 06:42:00 │  38.48 │                 1260.0 │
# │     0 │ 2002-09-02 06:22:00 │ 120.34 │                85200.0 │
# │     0 │ 2002-09-02 17:45:00 │ 128.95 │                40980.0 │
# │     0 │ 2002-09-03 06:23:00 │ 104.71 │                45480.0 │
# │     0 │ 2002-09-03 13:53:00 │  86.19 │                27000.0 │
# │     0 │ 2002-09-04 05:51:00 │  93.84 │                57480.0 │
# │     0 │ 2002-09-04 06:09:00 │  123.5 │                 1080.0 │
# │     0 │ 2002-09-05 06:14:00 │  61.72 │                86700.0 │
# │     0 │ 2002-09-05 09:35:00 │   57.1 │                12060.0 │
# │     0 │ 2002-09-05 20:18:00 │  76.07 │                38580.0 │
# │     0 │ 2002-09-05 20:41:00 │  53.91 │                 1380.0 │
# │     0 │ 2002-09-06 06:16:00 │ 110.37 │                34500.0 │
# │     0 │ 2002-09-07 06:16:00 │ 117.05 │                86400.0 │
# │     0 │ 2002-09-07 06:34:00 │   45.3 │                 1080.0 │
# ├───────┴─────────────────────┴────────┴────────────────────────┤
# │ 15 rows                                             4 columns │
# └───────────────────────────────────────────────────────────────┘

# %% [markdown]
# :::{tip} `EXTRACT(EPOCH FROM interval)` returns seconds
# `Datetime - LAG(Datetime)` is an `INTERVAL`. Wrapping it in
# `EXTRACT(EPOCH FROM ...)` converts it to a numeric number of seconds, which
# is what most downstream models expect.
# :::

# %% [markdown]
# ### A Composite Suspicious-Transaction Flag
#
# Combining a per-user average (computed in a CTE) with the per-row gap from the
# previous query gives us a SQL version of the fraud heuristic from the Polars
# notebook.

# %%
con.sql(
    """
WITH user_avg AS (
    SELECT "User", AVG("Amount") AS user_avg_amount
    FROM transactions
    GROUP BY "User"
),
with_gap AS (
    SELECT
        t.*,
        EXTRACT(EPOCH FROM
            t."Datetime" - LAG(t."Datetime") OVER (PARTITION BY t."User" ORDER BY t."Datetime")
        ) AS seconds_since_last_txn,
        u.user_avg_amount
    FROM transactions t
    LEFT JOIN user_avg u USING ("User")
)
SELECT
    is_suspicious,
    COUNT(*)                AS n_transactions,
    ROUND(AVG("Amount"), 2) AS avg_amount
FROM (
    SELECT
        *,
        ("Use Chip" = 'Online Transaction'
         AND "Amount" > user_avg_amount
         AND seconds_since_last_txn < 60) AS is_suspicious
    FROM with_gap
)
GROUP BY is_suspicious
"""
)
# Out:
# FloatProgress(value=0.0, layout=Layout(width='auto'), style=ProgressStyle(bar_color='black'))
# ┌───────────────┬────────────────┬────────────┐
# │ is_suspicious │ n_transactions │ avg_amount │
# │    boolean    │     int64      │   double   │
# ├───────────────┼────────────────┼────────────┤
# │ NULL          │            129 │     492.99 │
# │ false         │       24383263 │      43.62 │
# │ true          │           3508 │     116.76 │
# └───────────────┴────────────────┴────────────┘

# %% [markdown]
# :::{seealso} Polars and DuckDB express the same idea
# Compare the SQL above to the Polars version in the previous notebook. The
# business logic is identical; only the syntax changes. Picking the right tool
# is mostly a matter of taste, team conventions, and whether the data is
# already loaded as a DataFrame or sitting in Parquet on disk.
# :::

# %% [markdown]
# ## Conclusion
#
# You have replicated the data preprocessing pipeline using DuckDB. Then, you performed feature engineering and aggregation to extract meaningful insights!
