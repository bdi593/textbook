# %% [markdown]
# # Reading SEC Filings with `edgartools`
#
# In this notebook we will use the [`edgartools`](https://github.com/dgunning/edgartools) Python package to:
#
# 1. Look up a public company by its ticker symbol.
# 2. List its recent 10-K (annual report) filings.
# 3. Open the most recent 10-K and inspect its structure.
# 4. Extract a few named sections - _Business_, _Risk Factors_, and _Management's Discussion and Analysis_ - as clean plain text.
# 5. Save the extracted text to disk so the **next notebook** (`analyze-filings-with-llm.ipynb`) can feed it into an LLM.
#
# We pin `edgartools` to the **5.x** major version so the API calls below behave the same regardless of future major releases.

# %% [markdown]
# ## 1. Install and import
#
# You only need to run the install cell once per environment. The version pin (`>=5.0.0,<6.0.0`) prevents an accidental jump to a future 6.x release that may rename methods.
#
# Uncomment and run the cell below to install `edgartools`. Alternatively, you can install it from the command line with:
#
# ```bash
# pip install "edgartools>=5.0.0,<6.0.0"
# ```

# %%
# %pip install --quiet "edgartools>=5.0.0,<6.0.0"

# %%
import os
from pathlib import Path

import edgar
from edgar import Company, set_identity

# %% [markdown]
# Check `edgartools` version.

# %%
# %pip show edgartools
# Out:
# Name: edgartools
# Version: 5.30.0
# Summary: Python library to access and analyze SEC Edgar filings, XBRL financial statements, 10-K, 10-Q, and 8-K reports
# Home-page: https://github.com/dgunning/edgartools
# Author:
# Author-email: Dwight Gunning <dgunning@gmail.com>
# License-Expression: MIT
# Location: c:\Users\Park\miniconda3\Lib\site-packages
# Requires: beautifulsoup4, httpx, httpxthrottlecache, humanize, jinja2, lxml, nest-asyncio, orjson, pandas, pyarrow, pydantic, pyrate-limiter, rank-bm25, rapidfuzz, rich, stamina, tabulate, textdistance, tqdm, truststore, unidecode
# Required-by:
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ## 2. Identify yourself to the SEC
#
# The SEC's [fair-access policy](https://www.sec.gov/os/accessing-edgar-data) requires every automated request to include a contact email in the `User-Agent` header. `edgartools` exposes this through `set_identity()`. Use a real email address you actually monitor. Although rare, the SEC may contact you (or rate-limit you) if your scripts misbehave.
#
# Set the identity using `edgartool`'s `set_identity()` function, which configures the email included in the `User-Agent` header of all requests.

# %%
set_identity("John Doe jdoe@example.com")
print("SEC identity set.")
# Out:
# SEC identity set.

# %% [markdown]
# ## 3. Look up a company by ticker
#
# `edgar.Company` accepts either a ticker symbol (e.g. `"AAPL"`) or a CIK (Central Index Key, the SEC's internal company ID). Tickers are easier for humans; CIKs are more stable over time (companies sometimes change tickers).
#
# We will use Apple as our running example. Feel free to change `TICKER` to any large U.S. public company you are curious about.

# %%
TICKER = "AAPL"

company = Company(TICKER)
print(f"Name: {company.name}")
# Out:
# Name: Apple Inc.

# %% [markdown]
# Once you create the `Company` object, you can access metadata like the company's CIK.

# %%
print(f"CIK : {company.cik}")
# Out:
# CIK : 320193

# %% [markdown]
# ## 4. List 10-K filings
#
# Every public U.S. company files a 10-K once per fiscal year. We can ask `edgartools` to filter the company's full filing history down to just 10-Ks.

# %%
tenk_filings = company.get_filings(form="10-K")
tenk_filings.head(5)
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# ╭──────────────────────────────────────── Filings for Apple Inc. [320193] ────────────────────────────────────────╮
# │                                                                                                                 │
# │                                                                              Filing                             │
# │    Form        Description                                                   Date         Accession Number      │
# │  ─────────────────────────────────────────────────────────────────────────────────────────────────────────────  │
# │    10-K        Annual report for public companies                            2025-10-31   0000320193-25-0000…   │
# │    10-K        Annual report for public companies                            2024-11-01   0000320193-24-0001…   │
# │    10-K        Annual report for public companies                            2023-11-03   0000320193-23-0001…   │
# │    10-K        Annual report for public companies                            2022-10-28   0000320193-22-0001…   │
# │    10-K        Annual report for public companies                            2021-10-29   0000320193-21-0001…   │
# │                                                                                                                 │
# ╰─────────────── Company filings between 2021-10-29 and 2025-10-31 • filings.docs for usage guide ────────────────╯

# %% [markdown]
# The result is a `Filings` collection - think of it as a small DataFrame of metadata (form, filing date, accession number, primary document). Indexing it with `[0]` gives us the most recent filing as a `Filing` object.

# %%
latest_10k = tenk_filings[0]

print("Form           :", latest_10k.form)
print("Filed on       :", latest_10k.filing_date)
print("Period of report:", latest_10k.period_of_report)
print("Accession no.  :", latest_10k.accession_no)
print("Primary doc URL:", latest_10k.homepage_url)
# Out:
# Form           : 10-K
# Filed on       : 2025-10-31
# Period of report: 2025-09-27
# Accession no.  : 0000320193-25-000079
# Primary doc URL: https://www.sec.gov/Archives/edgar/data/320193/0000320193-25-000079-index.html

# %% [markdown]
# ## 5. Parse the 10-K into a structured object
#
# `Filing.obj()` returns a form-aware wrapper. For a 10-K, that wrapper is a `TenK` object that exposes named sections (Business, Risk Factors, MD&A, Financial Statements, …) as attributes. This is much friendlier than parsing the raw HTML yourself.

# %%
tenk = latest_10k.obj()
print("Object type:", type(tenk).__name__)
print("Available items:")
for item in tenk.items:
    print(" -", item)
# Out:
# Object type: TenK
# Available items:
#  - Item 1
#  - Item 7A
#  - Item 8
#  - Item 9
#  - Item 9A
#  - Item 9B
#  - Item 9C
#  - Item 10
#  - Item 11
#  - Item 12
#  - Item 13
#  - Item 14
#  - Item 15
#  - Item 16
#  - Item 1A
#  - Item 1B
#  - Item 1C
#  - Item 2
#  - Item 3
#  - Item 4
#  - Item 5
#  - Item 6
#  - Item 7

# %% [markdown]
# ## 6. Extract specific sections
#
# The three sections most useful for LLM analysis are:
#
# - **Item 1 — Business** (`tenk.business`): a long-form description of how the company makes money.
# - **Item 1A — Risk Factors** (`tenk.risk_factors`): the company's own enumeration of risks.
# - **Item 7 — Management's Discussion and Analysis** (`tenk.management_discussion`): management's narrative on results.
#
# Each accessor returns a plain Python `str` (already cleaned of HTML).

# %%
business_text = tenk.business or ""
risk_text = tenk.risk_factors or ""
mdna_text = tenk.management_discussion or ""

print(f"Business        : {len(business_text):>7,} characters")
print(f"Risk Factors    : {len(risk_text):>7,} characters")
print(f"MD&A            : {len(mdna_text):>7,} characters")
# Out:
# Business        :  16,054 characters
# Risk Factors    :  68,163 characters
# MD&A            :  18,018 characters

# %% [markdown]
# Let's preview the first ~800 characters of each section so we can sanity-check the extraction. A clean extraction should read like English prose, not like leftover HTML markup.

# %%
def preview(label: str, text: str, n: int = 800) -> None:
    print(f"\n=== {label} (first {n} chars) ===\n")
    print(text[:n].strip())
    print("..." if len(text) > n else "")


preview("BUSINESS", business_text)
preview("RISK FACTORS", risk_text)
preview("MD&A", mdna_text)
# Out:
# === BUSINESS (first 800 chars) ===
#
# Item 1.    Business
#
# Company Background
#
# The Company designs, manufactures and markets smartphones, personal computers, tablets, wearables and accessories, and sells a variety of related services. The Company’s fiscal year is the 52- or 53-week period that ends on the last Saturday of September.
#
# Products
#
# iPhone
#
# iPhone® is the Company’s line of smartphones based on its iOS operating system. The iPhone line includes iPhone 17 Pro, iPhone Air™, iPhone 17, iPhone 16 and iPhone 16e.
#
# Mac
#
# Mac® is the Company’s line of personal computers based on its macOS® operating system. The Mac line includes laptops MacBook Air® and MacBook Pro®, as well as desktops iMac®, Mac mini®, Mac Studio® and Mac Pro®.
#
# iPad
#
# iPad® is the Company’s line of multipurpose tablets based on its iPadOS® operating system
# ...
#
# === RISK FACTORS (first 800 chars) ===
#
# Item 1A.    Risk Factors
#
# The following summarizes factors that could have a material adverse effect on the Company’s business, reputation, results of operations, financial condition and stock price. The Company may not be able to accurately predict, control or mitigate these risks. Statements in this section are based on the Company’s beliefs and opinions regarding matters that could materially adversely affect the Company in the future and are not representations as to whether such matters have or have not occurred previously. The risks and uncertainties described below are not exhaustive and should not be considered a complete statement of all potential risks or uncertainties that the Company faces or may face in the future.
#
# This section should be read in conjunction with Part II, Item
# ...
#
# === MD&A (first 800 chars) ===
#
# Item 7.    Management’s Discussion and Analysis of Financial Condition and Results of Operations
#
# The following discussion should be read in conjunction with the consolidated financial statements and accompanying notes included in Part II, Item 8 of this Form 10-K. This Item generally discusses 2025 and 2024 items and year-to-year comparisons between 2025 and 2024. Discussions of 2023 items and year-to-year comparisons between 2024 and 2023 are not included, and can be found in “Management’s Discussion and Analysis of Financial Condition and Results of Operations” in Part II, Item 7 of the Company’s Annual Report on Form 10-K for the fiscal year ended September 28, 2024.
#
# Product, Service and Software Announcements
#
# The Company announces new product, service and software offerings at vario
# ...

# %% [markdown]
# ## 7. (Optional) Peek at the financial statements
#
# `edgartools` also parses the XBRL-tagged financial statements into pandas-friendly tables. We will not use these in the LLM notebook, but it is worth knowing they are available - they are useful for combining quantitative trends with the qualitative analysis the LLM will perform.
#
# First, retrieve the Income Statement object.

# %%
try:
    financials = tenk.financials
    income_statement = financials.income_statement()
    display(income_statement)
except Exception as exc:
    print("Financials not available for this filing:", exc)
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
#
#                                   APPLE INC.   AAPL
#                                   CONSOLIDATED STATEMENT OF INCOME
#                                   Sep 30, 2023 to Sep 27, 2025
#
#                                                        Sep 27, 2025   Sep 28, 2024   Sep 30, 2023
#    ───────────────────────────────────────────────────────────────────────────────────────────────
#             Net sales:                                     $416,161       $391,035       $383,285
#             Products                                       $307,003       $294,866       $298,085
#             Services                                       $109,158        $96,169        $85,200
#             Cost of sales:                                 $220,960       $210,352       $214,137
#             Products                                       $194,116       $185,233       $189,282
#             Services                                        $26,844        $25,119        $24,855
#           Gross margin                                     $195,201       $180,683       $169,148
#         Operating expenses:
#               Research and development:                     $34,550        $31,370        $29,915
#               Selling, general and administrative           $27,601        $26,097        $24,932
#               Total operating expenses                      $62,151        $57,467        $54,847
#             Operating income:                              $133,050       $123,216       $114,301
#             Other income/(expense), net                      $(321)           $269         $(565)
#           Income before provision for income taxes         $132,729       $123,485       $113,736
#           Provision for income taxes                        $20,719        $29,749        $16,741
#           Net income:                                      $112,010        $93,736        $96,995
#         Earnings per share:
#             Basic (in dollars per share)                       7.49           6.11           6.16
#             Diluted (in dollars per share)                     7.46           6.08           6.13
#         Shares used in computing earnings per share:
#             Basic (in shares)                            14,948,500     15,343,783     15,744,231
#             Diluted (in shares)                          15,004,697     15,408,095     15,812,547
#
#    Source: SEC XBRL  •  (In millions, except shares in thousands and per share data)

# %% [markdown]
# Then, convert it to a DataFrame for easier viewing. The same pattern works for the Balance Sheet and Cash Flow Statement.

# %%
if income_statement is not None:
    df_income_statement = income_statement.to_dataframe()
    display(df_income_statement)
# Out:
#                                               concept  \
# 0   us-gaap_RevenueFromContractWithCustomerExcludi...
# 1   us-gaap_RevenueFromContractWithCustomerExcludi...
# 2   us-gaap_RevenueFromContractWithCustomerExcludi...
# 3   us-gaap_RevenueFromContractWithCustomerExcludi...
# 4   us-gaap_RevenueFromContractWithCustomerExcludi...
# 5   us-gaap_RevenueFromContractWithCustomerExcludi...
# 6   us-gaap_RevenueFromContractWithCustomerExcludi...
# 7   us-gaap_RevenueFromContractWithCustomerExcludi...
# 8   us-gaap_RevenueFromContractWithCustomerExcludi...
# 9   us-gaap_RevenueFromContractWithCustomerExcludi...
# 10  us-gaap_RevenueFromContractWithCustomerExcludi...
# 11  us-gaap_RevenueFromContractWithCustomerExcludi...
# 12  us-gaap_RevenueFromContractWithCustomerExcludi...
# 13  us-gaap_RevenueFromContractWithCustomerExcludi...
# 14  us-gaap_RevenueFromContractWithCustomerExcludi...
# 15                 us-gaap_CostOfGoodsAndServicesSold
# 16                 us-gaap_CostOfGoodsAndServicesSold
# 17                 us-gaap_CostOfGoodsAndServicesSold
# 18                 us-gaap_CostOfGoodsAndServicesSold
# 19                 us-gaap_CostOfGoodsAndServicesSold
# 20                 us-gaap_CostOfGoodsAndServicesSold
# 21                 us-gaap_CostOfGoodsAndServicesSold
# 22                 us-gaap_CostOfGoodsAndServicesSold
# 23                                us-gaap_GrossProfit
# 24                  us-gaap_OperatingExpensesAbstract
# 25              us-gaap_ResearchAndDevelopmentExpense
# 26              us-gaap_ResearchAndDevelopmentExpense
# 27     us-gaap_SellingGeneralAndAdministrativeExpense
# 28                          us-gaap_OperatingExpenses
# 29                        us-gaap_OperatingIncomeLoss
# 30                        us-gaap_OperatingIncomeLoss
# 31                        us-gaap_OperatingIncomeLoss
# 32                        us-gaap_OperatingIncomeLoss
# 33                        us-gaap_OperatingIncomeLoss
# 34                        us-gaap_OperatingIncomeLoss
# 35                        us-gaap_OperatingIncomeLoss
# 36                  us-gaap_NonoperatingIncomeExpense
# 37  us-gaap_IncomeLossFromContinuingOperationsBefo...
# 38                    us-gaap_IncomeTaxExpenseBenefit
# 39                              us-gaap_NetIncomeLoss
# 40                              us-gaap_NetIncomeLoss
# 41                   us-gaap_EarningsPerShareAbstract
# 42                      us-gaap_EarningsPerShareBasic
# 43                    us-gaap_EarningsPerShareDiluted
# 44  us-gaap_WeightedAverageNumberOfSharesOutstandi...
# 45  us-gaap_WeightedAverageNumberOfSharesOutstandi...
# 46  us-gaap_WeightedAverageNumberOfDilutedSharesOu...
#
#                                            label  \
# 0                                      Net sales
# 1                                       Products
# 2                                         iPhone
# 3                                            Mac
# 4                                           iPad
# 5                Wearables, Home and Accessories
# 6                                       Services
# 7                  Operating segments - Americas
# 8                    Operating segments - Europe
# 9             Operating segments - Greater China
# 10                    Operating segments - Japan
# 11     Operating segments - Rest of Asia Pacific
# 12                                          U.S.
# 13                                         China
# 14                               Other countries
# 15                                 Cost of sales
# 16                                      Products
# 17                                      Services
# 18                 Operating segments - Americas
# 19                   Operating segments - Europe
# 20            Operating segments - Greater China
# 21                    Operating segments - Japan
# 22     Operating segments - Rest of Asia Pacific
# 23                                  Gross margin
# 24                           Operating expenses:
# 25                      Research and development
# 26                         Corporate non-segment
# 27           Selling, general and administrative
# 28                      Total operating expenses
# 29                              Operating income
# 30                 Operating segments - Americas
# 31                   Operating segments - Europe
# 32            Operating segments - Greater China
# 33                    Operating segments - Japan
# 34     Operating segments - Rest of Asia Pacific
# 35                         Corporate non-segment
# 36                   Other income/(expense), net
# 37      Income before provision for income taxes
# 38                    Provision for income taxes
# 39                                    Net income
# 40       Retained earnings/(Accumulated deficit)
# 41                           Earnings per share:
# 42                  Basic (in dollars per share)
# 43                Diluted (in dollars per share)
# 44  Shares used in computing earnings per share:
# 45                             Basic (in shares)
# 46                           Diluted (in shares)
#
#                   standard_concept  2025-09-27 (FY)  2024-09-28 (FY)  \
# 0                          Revenue     4.161610e+11     3.910350e+11
# 1                             None     3.070030e+11     2.948660e+11
# 2                             None     2.095860e+11     2.011830e+11
# 3                             None     3.370800e+10     2.998400e+10
# 4                             None     2.802300e+10     2.669400e+10
# 5                             None     3.568600e+10     3.700500e+10
# 6                             None     1.091580e+11     9.616900e+10
# 7                             None     1.783530e+11     1.670450e+11
# 8                             None     1.110320e+11     1.013280e+11
# 9                             None     6.437700e+10     6.695200e+10
# 10                            None     2.870300e+10     2.505200e+10
# 11                            None     3.369600e+10     3.065800e+10
# 12                            None     1.517900e+11     1.421960e+11
# 13                            None     6.437700e+10     6.695200e+10
# 14                            None     1.999940e+11     1.818870e+11
# 15      CostOfGoodsAndServicesSold     2.209600e+11     2.103520e+11
# 16                            None     1.941160e+11     1.852330e+11
# 17                            None     2.684400e+10     2.511900e+10
# 18                            None     9.569900e+10     8.958700e+10
# 19                            None     5.861700e+10     5.519700e+10
# 20                            None     3.514100e+10     3.751900e+10
# 21                            None     1.377900e+10     1.174400e+10
# 22                            None     1.772400e+10     1.630500e+10
# 23                     GrossProfit     1.952010e+11     1.806830e+11
# 24                            None              NaN              NaN
# 25  ResearchAndDevelopmentExpenses     3.455000e+10     3.137000e+10
# 26                            None     3.455000e+10     3.137000e+10
# 27  SellingGeneralAndAdminExpenses     2.760100e+10     2.609700e+10
# 28          TotalOperatingExpenses     6.215100e+10     5.746700e+10
# 29             OperatingIncomeLoss     1.330500e+11     1.232160e+11
# 30                            None     7.248000e+10     6.765600e+10
# 31                            None     4.773900e+10     4.179000e+10
# 32                            None     2.691700e+10     2.708200e+10
# 33                            None     1.395500e+10     1.245400e+10
# 34                            None     1.458600e+10     1.306200e+10
# 35                            None    -4.262700e+10    -3.882800e+10
# 36       NonoperatingIncomeExpense    -3.210000e+08     2.690000e+08
# 37                PretaxIncomeLoss     1.327290e+11     1.234850e+11
# 38                     IncomeTaxes     2.071900e+10     2.974900e+10
# 39                       NetIncome     1.120100e+11     9.373600e+10
# 40                            None     1.120100e+11     9.373600e+10
# 41                            None              NaN              NaN
# 42                            None     7.490000e+00     6.110000e+00
# 43                            None     7.460000e+00     6.080000e+00
# 44                            None              NaN              NaN
# 45                   SharesAverage     1.494850e+10     1.534378e+10
# 46       SharesFullyDilutedAverage     1.500470e+10     1.540810e+10
#
#     2023-09-30 (FY)  level  abstract  dimension  is_breakdown  \
# 0      3.832850e+11      4     False      False         False
# 1      2.980850e+11      4     False       True         False
# 2      2.005830e+11      4     False       True         False
# 3      2.935700e+10      4     False       True         False
# 4      2.830000e+10      4     False       True         False
# 5      3.984500e+10      4     False       True         False
# 6      8.520000e+10      4     False       True         False
# 7      1.625600e+11      4     False       True          True
# 8      9.429400e+10      4     False       True          True
# 9      7.255900e+10      4     False       True          True
# 10     2.425700e+10      4     False       True          True
# 11     2.961500e+10      4     False       True          True
# 12     1.385730e+11      4     False       True          True
# 13     7.255900e+10      4     False       True          True
# 14     1.721530e+11      4     False       True          True
# 15     2.141370e+11      4     False      False         False
# 16     1.892820e+11      4     False       True         False
# 17     2.485500e+10      4     False       True         False
# 18     9.239400e+10      4     False       True          True
# 19     5.410100e+10      4     False       True          True
# 20     3.978700e+10      4     False       True          True
# 21     1.154200e+10      4     False       True          True
# 22     1.631300e+10      4     False       True          True
# 23     1.691480e+11      3     False      False         False
# 24              NaN      3      True      False         False
# 25     2.991500e+10      5     False      False         False
# 26     2.991500e+10      5     False       True          True
# 27     2.493200e+10      5     False      False         False
# 28     5.484700e+10      5     False      False         False
# 29     1.143010e+11      4     False      False         False
# 30     6.050800e+10      4     False       True          True
# 31     3.609800e+10      4     False       True          True
# 32     3.032800e+10      4     False       True          True
# 33     1.188800e+10      4     False       True          True
# 34     1.206600e+10      4     False       True          True
# 35    -3.658700e+10      4     False       True          True
# 36    -5.650000e+08      4     False      False         False
# 37     1.137360e+11      3     False      False         False
# 38     1.674100e+10      3     False      False         False
# 39     9.699500e+10      3     False      False         False
# 40     9.699500e+10      4     False       True          True
# 41              NaN      3      True      False         False
# 42     6.160000e+00      4     False      False         False
# 43     6.130000e+00      4     False      False         False
# 44              NaN      3      True      False         False
# 45     1.574423e+10      4     False      False         False
# 46     1.581255e+10      4     False      False         False
#
#                            dimension_axis  \
# 0                                    None
# 1                srt:ProductOrServiceAxis
# 2                srt:ProductOrServiceAxis
# 3                srt:ProductOrServiceAxis
# 4                srt:ProductOrServiceAxis
# 5                srt:ProductOrServiceAxis
# 6                srt:ProductOrServiceAxis
# 7              srt:ConsolidationItemsAxis
# 8              srt:ConsolidationItemsAxis
# 9              srt:ConsolidationItemsAxis
# 10             srt:ConsolidationItemsAxis
# 11             srt:ConsolidationItemsAxis
# 12          srt:StatementGeographicalAxis
# 13          srt:StatementGeographicalAxis
# 14          srt:StatementGeographicalAxis
# 15                                   None
# 16               srt:ProductOrServiceAxis
# 17               srt:ProductOrServiceAxis
# 18             srt:ConsolidationItemsAxis
# 19             srt:ConsolidationItemsAxis
# 20             srt:ConsolidationItemsAxis
# 21             srt:ConsolidationItemsAxis
# 22             srt:ConsolidationItemsAxis
# 23                                   None
# 24                                   None
# 25                                   None
# 26             srt:ConsolidationItemsAxis
# 27                                   None
# 28                                   None
# 29                                   None
# 30             srt:ConsolidationItemsAxis
# 31             srt:ConsolidationItemsAxis
# 32             srt:ConsolidationItemsAxis
# 33             srt:ConsolidationItemsAxis
# 34             srt:ConsolidationItemsAxis
# 35             srt:ConsolidationItemsAxis
# 36                                   None
# 37                                   None
# 38                                   None
# 39                                   None
# 40  us-gaap:StatementEquityComponentsAxis
# 41                                   None
# 42                                   None
# 43                                   None
# 44                                   None
# 45                                   None
# 46                                   None
#
#                           dimension_member  \
# 0                                     None
# 1                    us-gaap_ProductMember
# 2                        aapl_IPhoneMember
# 3                           aapl_MacMember
# 4                          aapl_IPadMember
# 5   aapl_WearablesHomeandAccessoriesMember
# 6                    us-gaap_ServiceMember
# 7          us-gaap_OperatingSegmentsMember
# 8          us-gaap_OperatingSegmentsMember
# 9          us-gaap_OperatingSegmentsMember
# 10         us-gaap_OperatingSegmentsMember
# 11         us-gaap_OperatingSegmentsMember
# 12                              country_US
# 13                              country_CN
# 14               aapl_OtherCountriesMember
# 15                                    None
# 16                   us-gaap_ProductMember
# 17                   us-gaap_ServiceMember
# 18         us-gaap_OperatingSegmentsMember
# 19         us-gaap_OperatingSegmentsMember
# 20         us-gaap_OperatingSegmentsMember
# 21         us-gaap_OperatingSegmentsMember
# 22         us-gaap_OperatingSegmentsMember
# 23                                    None
# 24                                    None
# 25                                    None
# 26       us-gaap_CorporateNonSegmentMember
# 27                                    None
# 28                                    None
# 29                                    None
# 30         us-gaap_OperatingSegmentsMember
# 31         us-gaap_OperatingSegmentsMember
# 32         us-gaap_OperatingSegmentsMember
# 33         us-gaap_OperatingSegmentsMember
# 34         us-gaap_OperatingSegmentsMember
# 35       us-gaap_CorporateNonSegmentMember
# 36                                    None
# 37                                    None
# 38                                    None
# 39                                    None
# 40          us-gaap_RetainedEarningsMember
# 41                                    None
# 42                                    None
# 43                                    None
# 44                                    None
# 45                                    None
# 46                                    None
#
#                      dimension_member_label  \
# 0                                      None
# 1                                  Products
# 2                                    iPhone
# 3                                       Mac
# 4                                      iPad
# 5           Wearables, Home and Accessories
# 6                                  Services
# 7                        Operating segments
# 8                        Operating segments
# 9                        Operating segments
# 10                       Operating segments
# 11                       Operating segments
# 12                                     U.S.
# 13                                    China
# 14                          Other countries
# 15                                     None
# 16                                 Products
# 17                                 Services
# 18                       Operating segments
# 19                       Operating segments
# 20                       Operating segments
# 21                       Operating segments
# 22                       Operating segments
# 23                                     None
# 24                                     None
# 25                                     None
# 26                    Corporate non-segment
# 27                                     None
# 28                                     None
# 29                                     None
# 30                       Operating segments
# 31                       Operating segments
# 32                       Operating segments
# 33                       Operating segments
# 34                       Operating segments
# 35                    Corporate non-segment
# 36                                     None
# 37                                     None
# 38                                     None
# 39                                     None
# 40  Retained earnings/(Accumulated deficit)
# 41                                     None
# 42                                     None
# 43                                     None
# 44                                     None
# 45                                     None
# 46                                     None
#
#                                       dimension_label balance  weight  \
# 0                                                None  credit     1.0
# 1                  srt:ProductOrServiceAxis: Products  credit     1.0
# 2                    srt:ProductOrServiceAxis: iPhone  credit     1.0
# 3                       srt:ProductOrServiceAxis: Mac  credit     1.0
# 4                      srt:ProductOrServiceAxis: iPad  credit     1.0
# 5   srt:ProductOrServiceAxis: Wearables, Home and ...  credit     1.0
# 6                  srt:ProductOrServiceAxis: Services  credit     1.0
# 7   srt:ConsolidationItemsAxis: Operating segments...  credit     1.0
# 8   srt:ConsolidationItemsAxis: Operating segments...  credit     1.0
# 9   srt:ConsolidationItemsAxis: Operating segments...  credit     1.0
# 10  srt:ConsolidationItemsAxis: Operating segments...  credit     1.0
# 11  srt:ConsolidationItemsAxis: Operating segments...  credit     1.0
# 12                srt:StatementGeographicalAxis: U.S.  credit     1.0
# 13               srt:StatementGeographicalAxis: China  credit     1.0
# 14     srt:StatementGeographicalAxis: Other countries  credit     1.0
# 15                                               None   debit    -1.0
# 16                 srt:ProductOrServiceAxis: Products   debit    -1.0
# 17                 srt:ProductOrServiceAxis: Services   debit    -1.0
# 18  srt:ConsolidationItemsAxis: Operating segments...   debit    -1.0
# 19  srt:ConsolidationItemsAxis: Operating segments...   debit    -1.0
# 20  srt:ConsolidationItemsAxis: Operating segments...   debit    -1.0
# 21  srt:ConsolidationItemsAxis: Operating segments...   debit    -1.0
# 22  srt:ConsolidationItemsAxis: Operating segments...   debit    -1.0
# 23                                               None  credit     1.0
# 24                                               None     NaN     NaN
# 25                                               None   debit     1.0
# 26  srt:ConsolidationItemsAxis: Corporate non-segment   debit     1.0
# 27                                               None   debit     1.0
# 28                                               None    None    -1.0
# 29                                               None  credit     1.0
# 30  srt:ConsolidationItemsAxis: Operating segments...  credit     1.0
# 31  srt:ConsolidationItemsAxis: Operating segments...  credit     1.0
# 32  srt:ConsolidationItemsAxis: Operating segments...  credit     1.0
# 33  srt:ConsolidationItemsAxis: Operating segments...  credit     1.0
# 34  srt:ConsolidationItemsAxis: Operating segments...  credit     1.0
# 35  srt:ConsolidationItemsAxis: Corporate non-segment  credit     1.0
# 36                                               None    None     1.0
# 37                                               None  credit     1.0
# 38                                               None   debit    -1.0
# 39                                               None  credit     1.0
# 40  us-gaap:StatementEquityComponentsAxis: Retaine...  credit     1.0
# 41                                               None     NaN     NaN
# 42                                               None    None     NaN
# 43                                               None    None     NaN
# 44                                               None     NaN     NaN
# 45                                               None    None     1.0
# 46                                               None    None     1.0
#
#     preferred_sign                                     parent_concept  \
# 0              1.0                                us-gaap_GrossProfit
# 1              1.0                                us-gaap_GrossProfit
# 2              1.0                                us-gaap_GrossProfit
# 3              1.0                                us-gaap_GrossProfit
# 4              1.0                                us-gaap_GrossProfit
# 5              1.0                                us-gaap_GrossProfit
# 6              1.0                                us-gaap_GrossProfit
# 7              1.0                                us-gaap_GrossProfit
# 8              1.0                                us-gaap_GrossProfit
# 9              1.0                                us-gaap_GrossProfit
# 10             1.0                                us-gaap_GrossProfit
# 11             1.0                                us-gaap_GrossProfit
# 12             1.0                                us-gaap_GrossProfit
# 13             1.0                                us-gaap_GrossProfit
# 14             1.0                                us-gaap_GrossProfit
# 15             1.0                                us-gaap_GrossProfit
# 16             1.0                                us-gaap_GrossProfit
# 17             1.0                                us-gaap_GrossProfit
# 18             1.0                                us-gaap_GrossProfit
# 19             1.0                                us-gaap_GrossProfit
# 20             1.0                                us-gaap_GrossProfit
# 21             1.0                                us-gaap_GrossProfit
# 22             1.0                                us-gaap_GrossProfit
# 23             1.0                        us-gaap_OperatingIncomeLoss
# 24             NaN                                               None
# 25             1.0                          us-gaap_OperatingExpenses
# 26             1.0                          us-gaap_OperatingExpenses
# 27             1.0                          us-gaap_OperatingExpenses
# 28             1.0                        us-gaap_OperatingIncomeLoss
# 29             1.0  us-gaap_IncomeLossFromContinuingOperationsBefo...
# 30             1.0  us-gaap_IncomeLossFromContinuingOperationsBefo...
# 31             1.0  us-gaap_IncomeLossFromContinuingOperationsBefo...
# 32             1.0  us-gaap_IncomeLossFromContinuingOperationsBefo...
# 33             1.0  us-gaap_IncomeLossFromContinuingOperationsBefo...
# 34             1.0  us-gaap_IncomeLossFromContinuingOperationsBefo...
# 35             1.0  us-gaap_IncomeLossFromContinuingOperationsBefo...
# 36             1.0  us-gaap_IncomeLossFromContinuingOperationsBefo...
# 37             1.0                              us-gaap_NetIncomeLoss
# 38             1.0                              us-gaap_NetIncomeLoss
# 39             1.0                                               None
# 40             1.0                                               None
# 41             NaN                                               None
# 42             1.0                                               None
# 43             1.0                                               None
# 44             NaN                                               None
# 45             1.0  us-gaap_WeightedAverageNumberOfDilutedSharesOu...
# 46             1.0                                               None
#
#                               parent_abstract_concept
# 0                          us-gaap_StatementLineItems
# 1                          us-gaap_StatementLineItems
# 2                          us-gaap_StatementLineItems
# 3                          us-gaap_StatementLineItems
# 4                          us-gaap_StatementLineItems
# 5                          us-gaap_StatementLineItems
# 6                          us-gaap_StatementLineItems
# 7                          us-gaap_StatementLineItems
# 8                          us-gaap_StatementLineItems
# 9                          us-gaap_StatementLineItems
# 10                         us-gaap_StatementLineItems
# 11                         us-gaap_StatementLineItems
# 12                         us-gaap_StatementLineItems
# 13                         us-gaap_StatementLineItems
# 14                         us-gaap_StatementLineItems
# 15                         us-gaap_StatementLineItems
# 16                         us-gaap_StatementLineItems
# 17                         us-gaap_StatementLineItems
# 18                         us-gaap_StatementLineItems
# 19                         us-gaap_StatementLineItems
# 20                         us-gaap_StatementLineItems
# 21                         us-gaap_StatementLineItems
# 22                         us-gaap_StatementLineItems
# 23                         us-gaap_StatementLineItems
# 24                         us-gaap_StatementLineItems
# 25                  us-gaap_OperatingExpensesAbstract
# 26                  us-gaap_OperatingExpensesAbstract
# 27                  us-gaap_OperatingExpensesAbstract
# 28                  us-gaap_OperatingExpensesAbstract
# 29                         us-gaap_StatementLineItems
# 30                         us-gaap_StatementLineItems
# 31                         us-gaap_StatementLineItems
# 32                         us-gaap_StatementLineItems
# 33                         us-gaap_StatementLineItems
# 34                         us-gaap_StatementLineItems
# 35                         us-gaap_StatementLineItems
# 36                         us-gaap_StatementLineItems
# 37                         us-gaap_StatementLineItems
# 38                         us-gaap_StatementLineItems
# 39                         us-gaap_StatementLineItems
# 40                         us-gaap_StatementLineItems
# 41                         us-gaap_StatementLineItems
# 42                   us-gaap_EarningsPerShareAbstract
# 43                   us-gaap_EarningsPerShareAbstract
# 44                         us-gaap_StatementLineItems
# 45  us-gaap_WeightedAverageNumberOfSharesOutstandi...
# 46  us-gaap_WeightedAverageNumberOfSharesOutstandi...

# %% [markdown]
# ## 8. Save extracted text for the next notebook
#
# We persist each section to `extracted/` so the LLM notebook can read it back without re-querying the SEC. Sticking to plain `.txt` files keeps the data inspectable and avoids any pickle/portability headaches.

# %%
out_dir = Path("extracted")
out_dir.mkdir(exist_ok=True)

meta = {
    "ticker": TICKER,
    "company_name": company.name,
    "cik": str(company.cik),
    "form": latest_10k.form,
    "accession_no": latest_10k.accession_no,
    "filing_date": str(latest_10k.filing_date),
    "period_of_report": str(latest_10k.period_of_report),
}


# Write a small metadata header at the top of each file so the source is always traceable.
def write_section(name: str, text: str) -> Path:
    path = out_dir / f"{TICKER}_{name}.txt"
    header = (
        f"# Source: SEC EDGAR {meta['accession_no']} ({meta['form']})\n"
        f"# Company: {meta['company_name']} (CIK {meta['cik']}, ticker {meta['ticker']})\n"
        f"# Filed:   {meta['filing_date']}  |  Period: {meta['period_of_report']}\n"
        f"# Section: {name}\n\n"
    )
    path.write_text(header + text, encoding="utf-8")
    return path


paths = {
    "business": write_section("business", business_text),
    "risk_factors": write_section("risk_factors", risk_text),
    "mdna": write_section("mdna", mdna_text),
}

for name, path in paths.items():
    print(f"Wrote {name:<13} -> {path}  ({path.stat().st_size:>7,} bytes)")
# Out:
# Wrote business      -> extracted\AAPL_business.txt  ( 16,472 bytes)
# Wrote risk_factors  -> extracted\AAPL_risk_factors.txt  ( 69,105 bytes)
# Wrote mdna          -> extracted\AAPL_mdna.txt  ( 18,708 bytes)

# %% [markdown]
# ## 9. Recap
#
# We have:
#
# - Set the SEC identity required for polite, compliant API access.
# - Looked up Apple Inc. by ticker, listed its 10-K filings, and grabbed the most recent one.
# - Parsed the 10-K into a `TenK` object and extracted the _Business_, _Risk Factors_, and _MD&A_ sections as clean plain text.
# - Saved each section to disk under `extracted/` for downstream use.
#
# In the next page, we will load these `.txt` files and run a series of OpenAI-compatible chat-completion calls against them - some with free-form text outputs, some with strict JSON schemas.
#
# :::{tip} Try this on your own
# Re-run the notebook with a different `TICKER` (e.g. `"MSFT"`, `"NVDA"`, `"WMT"`) and compare how long each section is across companies. Risk Factor sections in particular vary a lot in length and tone between industries.
# :::
